# %%
import shutil

import geopandas as gpd
import leafmap

from geospatial_tools import DATA_DIR, TESTS_DIR
from geospatial_tools.planetary_computer.sentinel_2 import BestProductsForFeatures, download_and_process_sentinel2_asset
from geospatial_tools.raster import clip_raster_with_polygon
from geospatial_tools.stac import Asset
from geospatial_tools.vector import create_vector_grid_parallel, select_polygons_by_location, to_geopackage

# %%
TEST_TMP_DIR = TESTS_DIR / "test_notebooks/tmp_sentinel2"
TEST_TMP_DIR.mkdir(exist_ok=True)

# %% [markdown]
# ### Initial pre-processing
#
# The above layers were processed using QGIS.
#
# For the purpose of this analysis, only the contiguous lower 48 states have been conserved; smaller islands/land masses
# have also been striped.
#
# The S2 tiling grid has been trimmed to keep only the grid cells that overlap with the
# contiguous states.
#
# Since our area of study is quite large, the `EPSG:5070` projection was chosen, as it
# covers the whole area, introduces minimal distortion while preserving area.
#
# The files below have also been saved in this repository.

# %%
USA_POLYGON_FILE = DATA_DIR / "usa_polygon_5070.gpkg"
S2_USA_GRID_FILE = DATA_DIR / "s2_grid_usa_polygon_5070.gpkg"
usa_polygon = gpd.read_file(USA_POLYGON_FILE)
s2_grid = gpd.read_file(S2_USA_GRID_FILE)

# %%
usa_polygon
# Out:
#     AFFGEOID GEOID           NAME  \
# 0  0100000US    US  United States
#
#                                             geometry
# 0  MULTIPOLYGON (((-2116048.733 3142966.552, -211...

# %%
s2_grid
# Out:
#       name   folders                                        description  \
# 0    12TUP  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 1    12TYQ  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 2    12TYR  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 3    12TYN  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 4    12TYP  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# ..     ...       ...                                                ...
# 977  12TTM  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 978  12TUK  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 979  12TUQ  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 980  12TUR  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 981  12TUN  Features  TILE PROPERTIES<br><table border=0 cellpadding...
#
#                                               geometry
# 0    MULTIPOLYGON Z (((-1386334.944 2487548.77 0, -...
# 1    MULTIPOLYGON Z (((-976300.478 2523767.452 0, -...
# 2    MULTIPOLYGON Z (((-960099.705 2622374.255 0, -...
# 3    MULTIPOLYGON Z (((-1008622.024 2325748.358 0, ...
# 4    MULTIPOLYGON Z (((-992478.385 2424861.34 0, -8...
# ..                                                 ...
# 977  MULTIPOLYGON Z (((-1515431.586 2304192.826 0, ...
# 978  MULTIPOLYGON Z (((-1448525.813 2089886.667 0, ...
# 979  MULTIPOLYGON Z (((-1371006.917 2586590.133 0, ...
# 980  MULTIPOLYGON Z (((-1355793.563 2685354.08 0, -...
# 981  MULTIPOLYGON Z (((-1401759.785 2388321.4 0, -1...
#
# [982 rows x 4 columns]

# %% [markdown]
# ## Creating our grid
#
# From this, we want to create a grid of square polygons with which we will later on
# query the [Planetary Computer](https://planetarycomputer.microsoft.com/dataset/sentinel-2-l2a)
# Sentinel 2 dataset and clip the selected Sentinel 2 images.
#
# For the purpose of this notebook, the grid that will be created will use 10km by 10km squares to speed up
# processing.

# %%
grid_size = 10000
bbox = usa_polygon.total_bounds
grid_10km_filename = TEST_TMP_DIR / "polygon_grid_10km.gpkg"
print("Starting processing for [create_vector_grid_parallel]")
grid_10km = create_vector_grid_parallel(bounding_box=bbox, grid_size=grid_size, crs="EPSG:5070")
print(f"Printing len(grid_parallel) to check if grid contains same amount of polygons : {len(grid_10km)}")
to_geopackage(gdf=grid_10km, filename=grid_10km_filename)
# Out:
# Starting processing for [create_vector_grid_parallel]
# [2025-05-22 14:12:05] INFO       [MainThread][geospatial_tools.vector] Creating grid coordinates for bounding box [[-2356113.74289801   301469.31619713  2258154.44089948  3165721.6501298 ]]
# [2025-05-22 14:12:05] INFO       [MainThread][geospatial_tools.vector] Creating flattened grid coordinates
# [2025-05-22 14:12:05] INFO       [MainThread][geospatial_tools.vector] Number of workers used: 16
# [2025-05-22 14:12:05] INFO       [MainThread][geospatial_tools.vector] Allocating polygon array for [132594] polygons
# [2025-05-22 14:12:05] INFO       [MainThread][geospatial_tools.vector] Creating polygons from chunks
# [2025-05-22 14:12:07] INFO       [MainThread][geospatial_tools.vector] Managing properties
# [2025-05-22 14:12:07] INFO       [MainThread][geospatial_tools.utils] Creating EPSG code from following input : [EPSG:5070]
# [2025-05-22 14:12:07] INFO       [MainThread][geospatial_tools.vector] Creating spatial index
# [2025-05-22 14:12:07] INFO       [MainThread][geospatial_tools.vector] Generating polygon UUIDs
# Printing len(grid_parallel) to check if grid contains same amount of polygons : 132594
# [2025-05-22 14:12:08] INFO       [MainThread][geospatial_tools.vector] Starting writing process
# [2025-05-22 14:12:08] INFO       [MainThread][geospatial_tools.vector] File [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/polygon_grid_10km.gpkg] took 0.7184841632843018 seconds to write.
# PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/polygon_grid_10km.gpkg')

# %% [markdown]
# ### Selecting the useful polygons
#
# Now, since our grid was created using the extent of our input polygon (continental USA), we need to filter out the polygons that do not intersect with it.
#
# Doing this in Python is not the most efficient way to do things, but since it's a step that shouldn't be done over and over, it's not that critical.
#
# If ever you need to do this step in an efficient way because the data is just too big or too complex, it would be better off going through QGIS, PyGQIS, GDAL or
# some other more efficient way to do this operation.

# %%
intersecting_polygons_filename = TEST_TMP_DIR / "intersecting_polygon_grid_10km.gpkg"
print("Starting intersect selection")
intersecting_polygons = select_polygons_by_location(grid_10km, usa_polygon, num_of_workers=4)

# Optionally save to a new file
to_geopackage(intersecting_polygons, intersecting_polygons_filename)
# Out:
# Starting intersect selection
# [2025-05-22 14:12:08] INFO       [MainThread][geospatial_tools.vector] Number of workers used: 4
# [2025-05-22 14:12:13] INFO       [MainThread][geospatial_tools.vector] Concatenating results
# [2025-05-22 14:12:13] INFO       [MainThread][geospatial_tools.vector] Creating spatial index
# [2025-05-22 14:12:13] INFO       [MainThread][geospatial_tools.vector] Filtering columns of the results
# [2025-05-22 14:12:13] INFO       [MainThread][geospatial_tools.vector] Starting writing process
# [2025-05-22 14:12:13] INFO       [MainThread][geospatial_tools.vector] File [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/intersecting_polygon_grid_10km.gpkg] took 0.43907809257507324 seconds to write.
# PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/intersecting_polygon_grid_10km.gpkg')

# %% [markdown]
# ## Data processing pipeline prototype

# %% [markdown]
# ### Finding the best image for each S2 tiling grid

# %%
# This is the full list of S2 grids
s2_tile_grid_list = s2_grid["name"].to_list()
s2_tile_grid_list
# Out:
# ['12TUP',
#  '12TYQ',
#  '12TYR',
#  '12TYN',
#  '12TYP',
#  '12TYS',
#  '12TYT',
#  '11SMB',
#  '11SMC',
#  '11SLV',
#  '11SMA',
#  '11SMS',
#  '12UUV',
#  '11SMT',
#  '11SMD',
#  '11SMR',
#  '12UUU',
#  '11SNA',
#  '12TWS',
#  '11SNB',
#  '12TWT',
#  '11SMU',
#  '12TWQ',
#  '11SMV',
#  '12TWR',
#  '12TXM',
#  '11SNS',
#  '12TXN',
#  '11SNC',
#  '12TXK',
#  '11SND',
#  '12TXL',
#  '11SKD',
#  '12TXR',
#  '12TXS',
#  '11SKB',
#  '12TXP',
#  '11SKC',
#  '12TXQ',
#  '11SKU',
#  '12TYL',
#  '11SKV',
#  '12TYM',
#  '12TXT',
#  '11SKT',
#  '12TYK',
#  '11SLC',
#  '11SLD',
#  '11SLA',
#  '11SLB',
#  '11SLT',
#  '11SLU',
#  '19TBF',
#  '19TBG',
#  '19TDM',
#  '19TDN',
#  '19TEJ',
#  '19TEK',
#  '19TEN',
#  '19TEL',
#  '19TEM',
#  '18STE',
#  '18STF',
#  '19TCG',
#  '18STC',
#  '19TCH',
#  '18STD',
#  '18STJ',
#  '19TCF',
#  '19TCL',
#  '18STG',
#  '19TCM',
#  '18STH',
#  '19TCJ',
#  '19TCK',
#  '19TDF',
#  '19TDG',
#  '19TDK',
#  '19TDL',
#  '19TDJ',
#  '16TCQ',
#  '16TCR',
#  '16TCN',
#  '16TCP',
#  '16TDK',
#  '16TDL',
#  '16TCS',
#  '16TCT',
#  '16TDP',
#  '15RWQ',
#  '16TDQ',
#  '16TDM',
#  '15RXN',
#  '16TDN',
#  '15RXP',
#  '16TDT',
#  '16TEK',
#  '16TDR',
#  '16TDS',
#  '16SGB',
#  '15RXQ',
#  '16SGC',
#  '16SFJ',
#  '15RYN',
#  '16SGA',
#  '15RYP',
#  '16SGF',
#  '16SGG',
#  '16SGD',
#  '16SGE',
#  '16TBK',
#  '15RUQ',
#  '16TBL',
#  '16SGH',
#  '15RVN',
#  '16SGJ',
#  '15RVP',
#  '16TCL',
#  '16TCM',
#  '16TBM',
#  '16TCK',
#  '16TGL',
#  '15RVQ',
#  '16TGM',
#  '15RWN',
#  '16TGK',
#  '15RWP',
#  '16TGQ',
#  '16TGR',
#  '16TGN',
#  '15SUT',
#  '16TGP',
#  '15SUU',
#  '15SUR',
#  '15SUS',
#  '16TGS',
#  '15SVB',
#  '15SVC',
#  '15SUV',
#  '15SVA',
#  '15SVS',
#  '15SVT',
#  '16TEN',
#  '15SVD',
#  '16TEP',
#  '15SVR',
#  '16TEL',
#  '15SWA',
#  '16TEM',
#  '15SWB',
#  '16TES',
#  '15SVU',
#  '15SVV',
#  '16TEQ',
#  '16TER',
#  '15STA',
#  '16TFM',
#  '15RYQ',
#  '16TFN',
#  '17TNG',
#  '16TFK',
#  '15STD',
#  '16TFL',
#  '17TNE',
#  '15STR',
#  '16TFR',
#  '17TNF',
#  '15STB',
#  '16TFS',
#  '15STC',
#  '16TFP',
#  '15STU',
#  '16TFQ',
#  '15STV',
#  '15STS',
#  '17TPF',
#  '15STT',
#  '16RGU',
#  '17TPG',
#  '15SUC',
#  '16RGV',
#  '15SUD',
#  '16SBC',
#  '17TPE',
#  '15SUA',
#  '16SBD',
#  '15SUB',
#  '16SBA',
#  '16SBB',
#  '17TPH',
#  '16SBG',
#  '17TPJ',
#  '16SBH',
#  '17TLJ',
#  '16SBE',
#  '17TLK',
#  '16SBF',
#  '17TLG',
#  '16SCB',
#  '17TLH',
#  '16SCC',
#  '16SBJ',
#  '17TME',
#  '16SCA',
#  '17TLL',
#  '17TLM',
#  '16REU',
#  '16REV',
#  '17TMF',
#  '17TMG',
#  '16RFT',
#  '16RFU',
#  '16RFV',
#  '16RGT',
#  '16SED',
#  '16SEE',
#  '16SEB',
#  '16SEC',
#  '16SEH',
#  '16SEJ',
#  '16SEF',
#  '16SEG',
#  '16SFC',
#  '16SFD',
#  '17TQE',
#  '16SFA',
#  '17TQF',
#  '15RTN',
#  '16SFB',
#  '15RTP',
#  '16SFG',
#  '16SFH',
#  '17TQJ',
#  '15RTM',
#  '16SFE',
#  '16SFF',
#  '17TQG',
#  '16SCF',
#  '17TQH',
#  '15RTQ',
#  '16SCG',
#  '16SCD',
#  '15RUN',
#  '16SCE',
#  '15RUP',
#  '16SDA',
#  '16SDB',
#  '16SCH',
#  '16SCJ',
#  '16SDE',
#  '16SDF',
#  '17SLR',
#  '16SDC',
#  '17SLS',
#  '16SDD',
#  '17SLC',
#  '16SDJ',
#  '17SLD',
#  '16SEA',
#  '17SLV',
#  '16SDG',
#  '17SMA',
#  '16SDH',
#  '17SLT',
#  '17SLU',
#  '17SMD',
#  '17SMR',
#  '17SMB',
#  '17SMC',
#  '17SMU',
#  '17SMV',
#  '17SMS',
#  '17SMT',
#  '17SKB',
#  '17SKC',
#  '17SKA',
#  '17SKS',
#  '17SKT',
#  '17SKD',
#  '17SKR',
#  '17SLA',
#  '17SLB',
#  '17SKU',
#  '17SKV',
#  '17SQA',
#  '17SQB',
#  '17SPU',
#  '17SPV',
#  '17SQC',
#  '17SQD',
#  '17SQV',
#  '16RCU',
#  '17TKE',
#  '16RCV',
#  '17SQT',
#  '17SQU',
#  '17TLE',
#  '17TLF',
#  '17TKF',
#  '17TKG',
#  '17SNC',
#  '16RDU',
#  '17SND',
#  '16RDV',
#  '17SNA',
#  '17SNB',
#  '17SNT',
#  '17SNU',
#  '17SNR',
#  '17SNS',
#  '17SPB',
#  '17SPC',
#  '17SNV',
#  '17SPA',
#  '16RBT',
#  '17SPS',
#  '17SPT',
#  '17SPD',
#  '16RBU',
#  '16RBV',
#  '16RCT',
#  '17RKQ',
#  '17RKN',
#  '17RKP',
#  '17RLL',
#  '17RLM',
#  '17RLK',
#  '17RNN',
#  '18TYN',
#  '18TYP',
#  '18TYL',
#  '17RLQ',
#  '18TYM',
#  '17RMH',
#  '17RLN',
#  '17RLP',
#  '18TYQ',
#  '17RML',
#  '18TYR',
#  '17RMM',
#  '17RMJ',
#  '17RMK',
#  '17RMQ',
#  '17RNH',
#  '18TWL',
#  '17RMN',
#  '18TWM',
#  '17RMP',
#  '17RNL',
#  '18TWK',
#  '17RNM',
#  '18TWQ',
#  '17RNJ',
#  '17RNK',
#  '18TWN',
#  '18TWP',
#  '18TXK',
#  '18TXL',
#  '18TXP',
#  '18TXQ',
#  '18TXM',
#  '18TXN',
#  '13TEL',
#  '13TEM',
#  '13TEJ',
#  '13TEK',
#  '13TFF',
#  '13TFG',
#  '13TEN',
#  '13TFE',
#  '12STC',
#  '13TFK',
#  '12STD',
#  '13TFL',
#  '12STA',
#  '14UQV',
#  '13TFH',
#  '12STB',
#  '13TFJ',
#  '12STG',
#  '13TGE',
#  '12STH',
#  '14UQU',
#  '13TGF',
#  '12STE',
#  '13TFM',
#  '12STF',
#  '13TFN',
#  '12SUB',
#  '18SVJ',
#  '13TCN',
#  '12SUC',
#  '13TDE',
#  '12STJ',
#  '13TCL',
#  '12SUA',
#  '13TCM',
#  '12SUF',
#  '13TDH',
#  '12SUG',
#  '13TDJ',
#  '12SUD',
#  '13TDF',
#  '12SUE',
#  '13TDG',
#  '13TDM',
#  '18SWJ',
#  '19TFK',
#  '13TDN',
#  '19TFL',
#  '13TDK',
#  '13TDL',
#  '13TEG',
#  '13TEH',
#  '18SUD',
#  '13TEE',
#  '12RXV',
#  '18SUE',
#  '13TEF',
#  '13UDP',
#  '13UDQ',
#  '18SUH',
#  '18SUJ',
#  '18SUF',
#  '18SUG',
#  '12RYV',
#  '18SVD',
#  '12SWH',
#  '12SWJ',
#  '13UEP',
#  '12SWF',
#  '18SVG',
#  '12SWG',
#  '18SVH',
#  '12SXC',
#  '18SVE',
#  '12SXD',
#  '18SVF',
#  '12SXA',
#  '18TUN',
#  '13UEQ',
#  '12SXB',
#  '18TUP',
#  '12SXG',
#  '18TUL',
#  '13TGJ',
#  '12SXH',
#  '18TUM',
#  '13TGK',
#  '12SXE',
#  '13TGG',
#  '12SXF',
#  '13TGH',
#  '12SYB',
#  '18TUQ',
#  '13TGN',
#  '12SYC',
#  '12SXJ',
#  '18TVM',
#  '13TGL',
#  '12SYA',
#  '18TVN',
#  '13TGM',
#  '12SVA',
#  '18TVK',
#  '13UCQ',
#  '12SVB',
#  '18TVL',
#  '12SUH',
#  '14TQN',
#  '12SUJ',
#  '14TQP',
#  '13UCP',
#  '12SVE',
#  '14TQL',
#  '18TVP',
#  '12SVF',
#  '14TQM',
#  '18TVQ',
#  '12SVC',
#  '14TQS',
#  '12SVD',
#  '14TQT',
#  '12SVJ',
#  '14TQQ',
#  '13SCV',
#  '12SWA',
#  '14TQR',
#  '13SDA',
#  '12SVG',
#  '13SCT',
#  '12SVH',
#  '13SCU',
#  '12SWD',
#  '13SDD',
#  '12SWE',
#  '13SDR',
#  '12SWB',
#  '13SDB',
#  '12SWC',
#  '14ULU',
#  '13SDC',
#  '13SDU',
#  '13SDV',
#  '14TNQ',
#  '18TTM',
#  '13SDS',
#  '14TNR',
#  '18TUK',
#  '13SDT',
#  '14TNN',
#  '18TTK',
#  '13SEC',
#  '14TNP',
#  '18TTL',
#  '13SED',
#  '14TPK',
#  '13SEA',
#  '14TPL',
#  '13SEB',
#  '14TNS',
#  '13SBB',
#  '14TNT',
#  '13SBC',
#  '14TPP',
#  '14TPQ',
#  '13SBA',
#  '14TPM',
#  '13SBS',
#  '14TPN',
#  '13SBT',
#  '14TPT',
#  '13SBD',
#  '14TQK',
#  '13SBR',
#  '14TPR',
#  '13SCA',
#  '14TPS',
#  '13SCB',
#  '14UNV',
#  '13SBU',
#  '13SBV',
#  '13SCR',
#  '14UNU',
#  '13SCS',
#  '13SCC',
#  '13SCD',
#  '13SGR',
#  '13SGS',
#  '14UPU',
#  '13SGC',
#  '14UPV',
#  '13SGD',
#  '13SGV',
#  '13TBE',
#  '13SGT',
#  '13SGU',
#  '13TCE',
#  '13TCF',
#  '13TBF',
#  '13TBG',
#  '14ULV',
#  '13TCJ',
#  '13TCK',
#  '13TCG',
#  '12RVV',
#  '13TCH',
#  '13SET',
#  '13SEU',
#  '13SER',
#  '13SES',
#  '14UMU',
#  '13SFB',
#  '14UMV',
#  '13SFC',
#  '13SEV',
#  '12RWV',
#  '13SFA',
#  '13SFS',
#  '15UVP',
#  '14SNF',
#  '13SFT',
#  '15UVQ',
#  '14SNG',
#  '13SFD',
#  '14SND',
#  '13SFR',
#  '14SNE',
#  '13SGA',
#  '14SPA',
#  '13SGB',
#  '14SPB',
#  '13SFU',
#  '14SNH',
#  '13SFV',
#  '14SNJ',
#  '14SPE',
#  '15UWP',
#  '14SPF',
#  '15TYG',
#  '14SPC',
#  '15TYH',
#  '14SPD',
#  '15TYE',
#  '14SPJ',
#  '15TYF',
#  '14SQA',
#  '12RUV',
#  '15TYL',
#  '14SPG',
#  '15TYM',
#  '14SPH',
#  '15TYJ',
#  '14SLH',
#  '15TYK',
#  '14SLJ',
#  '14SLF',
#  '15UUP',
#  '14SLG',
#  '13RCQ',
#  '15TYN',
#  '14SMC',
#  '14SMD',
#  '14SMA',
#  '14SMB',
#  '15UUQ',
#  '14SMG',
#  '14SMH',
#  '14SME',
#  '14SMF',
#  '14SNB',
#  '14SNC',
#  '14SMJ',
#  '14SNA',
#  '14TLS',
#  '14TLT',
#  '14TLQ',
#  '14TLR',
#  '14TMM',
#  '14TMN',
#  '14TMK',
#  '14TML',
#  '14TMR',
#  '14TMS',
#  '14TMP',
#  '14TMQ',
#  '13RFQ',
#  '14TNL',
#  '13RFN',
#  '14TNM',
#  '15UXP',
#  '13RFP',
#  '14TMT',
#  '14TNK',
#  '14SQD',
#  '14SQE',
#  '14SQB',
#  '14SQC',
#  '13RGQ',
#  '14SQH',
#  '14SQJ',
#  '13RGN',
#  '14SQF',
#  '13RGP',
#  '14SQG',
#  '14TKM',
#  '15UYP',
#  '14TLK',
#  '15SYC',
#  '14TKK',
#  '15SYD',
#  '14TKL',
#  '13RDQ',
#  '15SYA',
#  '14TLN',
#  '15SYB',
#  '14TLP',
#  '15SYT',
#  '14TLL',
#  '13RDP',
#  '15SYU',
#  '14TLM',
#  '15SYR',
#  '14RMQ',
#  '15SYS',
#  '14RMR',
#  '15TTF',
#  '15TTG',
#  '13REQ',
#  '15SYV',
#  '14RMU',
#  '15TTE',
#  '14RMV',
#  '13REN',
#  '15TUG',
#  '16UCU',
#  '14RMS',
#  '13REP',
#  '15TUH',
#  '14RMT',
#  '15TUE',
#  '14RNQ',
#  '15TUF',
#  '14RNR',
#  '15SWR',
#  '15SWS',
#  '14RNP',
#  '15SWC',
#  '14RNU',
#  '15SWD',
#  '14RNV',
#  '15SWV',
#  '14RNS',
#  '15SXA',
#  '14RNT',
#  '15SWT',
#  '15SWU',
#  '15SXD',
#  '15SXR',
#  '15SXB',
#  '14RKU',
#  '15SXC',
#  '14RKV',
#  '15SXU',
#  '15SXV',
#  '14RKT',
#  '15SXS',
#  '15SXT',
#  '14RLR',
#  '15TWJ',
#  '15TWK',
#  '15TWG',
#  '14RLU',
#  '15TWH',
#  '14RLV',
#  '15TWN',
#  '14RLS',
#  '15TXE',
#  '14RLT',
#  '15TWL',
#  '14SKA',
#  '15TWM',
#  '14SKB',
#  '15TXH',
#  '15TXJ',
#  '15TXF',
#  '14SKE',
#  '15TXG',
#  '14SKF',
#  '15TXM',
#  '14SKC',
#  '15TXN',
#  '14SKD',
#  '15TXK',
#  '14SKJ',
#  '15TXL',
#  '14SLA',
#  '15TUL',
#  '14SKG',
#  '15TUM',
#  '14SKH',
#  '15TUJ',
#  '14SLD',
#  '15TUK',
#  '14SLE',
#  '15TVF',
#  '14SLB',
#  '15TVG',
#  '14SLC',
#  '15TUN',
#  '14RPQ',
#  '15TVE',
#  '14RPR',
#  '15TVK',
#  '15TVL',
#  '14RPP',
#  '15TVH',
#  '14RPU',
#  '15TVJ',
#  '14RPV',
#  '15TWE',
#  '14RPS',
#  '15TWF',
#  '14RPT',
#  '15TVM',
#  '15TVN',
#  '14RQR',
#  '14RQU',
#  '14RQV',
#  '14RQS',
#  '14RQT',
#  '10TGS',
#  '10TGT',
#  '10TGQ',
#  '10TGR',
#  '10UCU',
#  '10TFK',
#  '10TFL',
#  '10TES',
#  '10TET',
#  '10TFP',
#  '10TFQ',
#  '10TFM',
#  '10TFN',
#  '10TFT',
#  '10TGK',
#  '10TFR',
#  '10TFS',
#  '10TGN',
#  '10TGP',
#  '10TGL',
#  '10TGM',
#  '10UFU',
#  '10UFV',
#  '10UGV',
#  '10UGU',
#  '10UDU',
#  '11UMP',
#  '11UMQ',
#  '10UEV',
#  '10UEU',
#  '11UNQ',
#  '10SEH',
#  '10SEJ',
#  '11UNP',
#  '10SFE',
#  '10SFF',
#  '10SFD',
#  '10SFJ',
#  '11TQL',
#  '11TQM',
#  '10SFG',
#  '11TQJ',
#  '10SFH',
#  '11TQK',
#  '10SGD',
#  '10SGE',
#  '11ULP',
#  '11TQN',
#  '11ULQ',
#  '10SDH',
#  '10SDJ',
#  '10SEF',
#  '10SEG',
#  '10TDM',
#  '10TDN',
#  '10TDK',
#  '10TDL',
#  '10TDR',
#  '10TDS',
#  '10TDP',
#  '10TDQ',
#  '10TEL',
#  '11UPP',
#  '10TEM',
#  '11UPQ',
#  '10TDT',
#  '10TEK',
#  '10TEQ',
#  '10TER',
#  '10TEN',
#  '10TEP',
#  '10SGH',
#  '11UQQ',
#  '10SGJ',
#  '10SGF',
#  '10SGG',
#  '12UWV',
#  '11UQP',
#  '10TCK',
#  '10TCN',
#  '11SQT',
#  '10TCP',
#  '11SQU',
#  '10TCL',
#  '11SQR',
#  '10TCM',
#  '12UXU',
#  '11SQS',
#  '12UXV',
#  '11TKF',
#  '10TCT',
#  '11TKG',
#  '12UYU',
#  '11SQV',
#  '11TKE',
#  '11TLG',
#  '11TLH',
#  '11TLE',
#  '11TLF',
#  '11TLL',
#  '12UVU',
#  '11TLM',
#  '12UVV',
#  '11TLJ',
#  '11TLK',
#  '11SNV',
#  '11SPA',
#  '11SNT',
#  '11SNU',
#  '11SPD',
#  '11SPR',
#  '12UWU',
#  '11SPB',
#  '11SPC',
#  '11SPU',
#  '11SPV',
#  '11SPS',
#  '11SPT',
#  '11SQC',
#  '11SQD',
#  '11SQA',
#  '11SQB',
#  '11TNN',
#  '11TPE',
#  '11TNL',
#  '11TNM',
#  '11TPH',
#  '11TPJ',
#  '11TPF',
#  '11TPG',
#  '11TPM',
#  '11TPN',
#  '11TPK',
#  '12UYV',
#  '11TPL',
#  '11TQG',
#  '11TQH',
#  '11TQE',
#  '11TQF',
#  '11TMF',
#  '11TMG',
#  '11TLN',
#  '11TME',
#  '11TMK',
#  '11TML',
#  '11TMH',
#  '11TMJ',
#  '11TNE',
#  '12TVK',
#  '11TNF',
#  '12TVL',
#  '11TMM',
#  '12TUS',
#  '11TMN',
#  '12TUT',
#  '11TNJ',
#  '12TVP',
#  '11TNK',
#  '12TVQ',
#  '11TNG',
#  '12TVM',
#  '11TNH',
#  '12TVN',
#  '12TVT',
#  '12TWK',
#  '12TVR',
#  '12TVS',
#  '12TWN',
#  '12TWP',
#  '12TWL',
#  '13UFP',
#  '12TWM',
#  '13UFQ',
#  '12SYF',
#  '12SYG',
#  '13UGP',
#  '12SYD',
#  '12SYE',
#  '12TTK',
#  '11SKA',
#  '12TTL',
#  '12SYH',
#  '13UGQ',
#  '12SYJ',
#  '12TUL',
#  '12TUM',
#  '12TTM',
#  '12TUK',
#  '12TUQ',
#  '12TUR',
#  '12TUN']

# %%
# The list is a bit long, so we'll be continuing this notebook with the following subset
s2_tile_grid_subset_list = ["10TDK", "10TEK", "10SDJ"]

# %% [markdown]
# ### Building our processing list
#
# First, let's make create a subselection of our dataset

# %%
S2_USA_GRID_FILE = DATA_DIR / "s2_grid_usa_polygon_5070.gpkg"
s2_grid = gpd.read_file(S2_USA_GRID_FILE)
s2_grid
# Out:
#       name   folders                                        description  \
# 0    12TUP  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 1    12TYQ  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 2    12TYR  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 3    12TYN  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 4    12TYP  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# ..     ...       ...                                                ...
# 977  12TTM  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 978  12TUK  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 979  12TUQ  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 980  12TUR  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 981  12TUN  Features  TILE PROPERTIES<br><table border=0 cellpadding...
#
#                                               geometry
# 0    MULTIPOLYGON Z (((-1386334.944 2487548.77 0, -...
# 1    MULTIPOLYGON Z (((-976300.478 2523767.452 0, -...
# 2    MULTIPOLYGON Z (((-960099.705 2622374.255 0, -...
# 3    MULTIPOLYGON Z (((-1008622.024 2325748.358 0, ...
# 4    MULTIPOLYGON Z (((-992478.385 2424861.34 0, -8...
# ..                                                 ...
# 977  MULTIPOLYGON Z (((-1515431.586 2304192.826 0, ...
# 978  MULTIPOLYGON Z (((-1448525.813 2089886.667 0, ...
# 979  MULTIPOLYGON Z (((-1371006.917 2586590.133 0, ...
# 980  MULTIPOLYGON Z (((-1355793.563 2685354.08 0, -...
# 981  MULTIPOLYGON Z (((-1401759.785 2388321.4 0, -1...
#
# [982 rows x 4 columns]

# %%
# Creating our S2 grid tile subset

S2_USA_GRID_SUBSET_FILE = TEST_TMP_DIR / "s2_grid_usa_polygon_5070_subset.gpkg"
s2_grid_subset = s2_grid[s2_grid["name"].isin(s2_tile_grid_subset_list)]

# Optionally save to geopackage
to_geopackage(gdf=s2_grid_subset, filename=S2_USA_GRID_SUBSET_FILE)
# Out:
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] Starting writing process
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] File [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/s2_grid_usa_polygon_5070_subset.gpkg] took 0.02459549903869629 seconds to write.
# PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/s2_grid_usa_polygon_5070_subset.gpkg')

# %%
s2_grid_subset
# Out:
#       name   folders                                        description  \
# 841  10SDJ  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 846  10TDK  Features  TILE PROPERTIES<br><table border=0 cellpadding...
# 857  10TEK  Features  TILE PROPERTIES<br><table border=0 cellpadding...
#
#                                               geometry
# 841  MULTIPOLYGON Z (((-2357236.175 2210256.163 0, ...
# 846  MULTIPOLYGON Z (((-2329019.777 2307113.875 0, ...
# 857  MULTIPOLYGON Z (((-2233778.019 2279366.081 0, ...

# %%
# Creating our polygon grid subset

intersect_polygons_subset_filename = TEST_TMP_DIR / "intersecting_polygon_grid_10km_subset.gpkg"
print("Starting intersect selection")
intersect_polygons_subset = select_polygons_by_location(
    intersecting_polygons, s2_grid_subset, predicate="within", num_of_workers=4
)
# intersect_polygons_subset = gpd.read_file(intersect_polygons_subset_filename)

# Optionally save to a new file
to_geopackage(intersect_polygons_subset, intersect_polygons_subset_filename)
# Out:
# Starting intersect selection
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] Number of workers used: 4
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] Concatenating results
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] Creating spatial index
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] Dropping duplicates
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] Filtering columns of the results
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] Starting writing process
# [2025-05-22 14:12:14] INFO       [MainThread][geospatial_tools.vector] File [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/intersecting_polygon_grid_10km_subset.gpkg] took 0.03481006622314453 seconds to write.
# PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/intersecting_polygon_grid_10km_subset.gpkg')

# %% [markdown]
# ### Finding the best products for our subset use case

# %%
s2_feature_name_columns = "name"
vector_column_name = "s2_tiles"

# Initiating our client
best_products_client = BestProductsForFeatures(
    sentinel2_tiling_grid=s2_grid_subset,
    sentinel2_tiling_grid_column=s2_feature_name_columns,
    vector_features=intersect_polygons_subset,
    vector_features_column=vector_column_name,
    max_cloud_cover=15,
)

# %%
# NBVAL_IGNORE_OUTPUT

# Executing the search
#
# This search look only for complete products, meaning products with less than
# 5 percent of nodata.

start_year = 2024
end_year = 2024
start_month = 6
end_month = 7

best_products_client.create_date_ranges(start_year, end_year, start_month, end_month)
products = best_products_client.find_best_complete_products()
# Out:
# [2025-05-22 14:12:15] INFO       [ThreadPoolExecutor-0_0][geospatial_tools.stac] Running STAC API search for the following parameters:
# 	Date ranges : ['2024-06-01T00:00:00Z/2024-07-31T23:59:59Z']
# 	Query : {'eo:cloud_cover': {'lt': 15}, 's2:mgrs_tile': {'in': ['10SDJ']}}
# [2025-05-22 14:12:15] INFO       [ThreadPoolExecutor-0_1][geospatial_tools.stac] Running STAC API search for the following parameters:
# 	Date ranges : ['2024-06-01T00:00:00Z/2024-07-31T23:59:59Z']
# 	Query : {'eo:cloud_cover': {'lt': 15}, 's2:mgrs_tile': {'in': ['10TDK']}}
# [2025-05-22 14:12:15] INFO       [ThreadPoolExecutor-0_2][geospatial_tools.stac] Running STAC API search for the following parameters:
# 	Date ranges : ['2024-06-01T00:00:00Z/2024-07-31T23:59:59Z']
# 	Query : {'eo:cloud_cover': {'lt': 15}, 's2:mgrs_tile': {'in': ['10TEK']}}
# [2025-05-22 14:12:16] WARNING    [MainThread][geospatial_tools.planetary_computer.sentinel_2] Warning, some of the input Sentinel 2 tiles do not have products covering the entire tile. These tiles will need to be handled differently (ex. creating a mosaic with multiple products
# [2025-05-22 14:12:16] WARNING    [MainThread][geospatial_tools.planetary_computer.sentinel_2] Incomplete list: ['10TEK']

# %%
products
# Out:
# {'10SDJ': {'id': 'S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346',
#   'cloud_cover': 0.006778,
#   'no_data': 1.7e-05},
#  '10TDK': {'id': 'S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412',
#   'cloud_cover': 0.000707,
#   'no_data': 1e-05}}

# %%
# Selecting the best products for each vector tile
# This step is necessary as some of our vector polygons can be withing multiple S2 tiles.
# The best available S2 tile is therefore selected for each vector polygon.

best_results_path = TEST_TMP_DIR / "vector_tiles_with_s2tiles_subset.gpkg"
best_results = best_products_client.select_best_products_per_feature()
to_geopackage(best_results, best_results_path)
# Out:
# [2025-05-22 14:12:16] INFO       [MainThread][geospatial_tools.vector] Creating temporary UUID field for join operations
# [2025-05-22 14:12:16] INFO       [MainThread][geospatial_tools.vector] Starting process to find and identify contained features using spatial 'within' join operation
# [2025-05-22 14:12:16] INFO       [MainThread][geospatial_tools.vector] Grouping results
# [2025-05-22 14:12:16] INFO       [MainThread][geospatial_tools.vector] Cleaning and merging results
# [2025-05-22 14:12:16] INFO       [MainThread][geospatial_tools.vector] Spatial join operation is completed
# [2025-05-22 14:12:16] INFO       [MainThread][geospatial_tools.planetary_computer.sentinel_2] Writing best product IDs to dataframe
# [2025-05-22 14:12:16] INFO       [MainThread][geospatial_tools.vector] Starting writing process
# [2025-05-22 14:12:17] INFO       [MainThread][geospatial_tools.vector] File [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/vector_tiles_with_s2tiles_subset.gpkg] took 0.024296045303344727 seconds to write.
# PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/vector_tiles_with_s2tiles_subset.gpkg')

# %% [markdown]
# ### Visualizing the results

# %%
best_products_client.successful_results
# Out:
# {'10SDJ': {'id': 'S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346',
#   'cloud_cover': 0.006778,
#   'no_data': 1.7e-05},
#  '10TDK': {'id': 'S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412',
#   'cloud_cover': 0.000707,
#   'no_data': 1e-05}}

# %%
best_products_client.incomplete_results
# Out:
# ['10TEK']

# %%
m_best_results = leafmap.Map(center=[39.7, -123], zoom=8)
m_best_results.add_gdf(s2_grid_subset, layer_name="s2_tiles", style={"color": "red"})
m_best_results.add_gdf(best_results, layer_name="vector_tiles_s2_grid", style={"color": "green"})
m_best_results
# Out:
# Map(center=[39.7, -123], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…

# %%
# NBVAL_IGNORE_OUTPUT
group_by_product = best_results.groupby("best_s2_product_id")["feature_id"].agg(list).reset_index()

# %%
product_list = group_by_product["best_s2_product_id"].tolist()
sorted(product_list)
# Out:
# ['S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346',
#  'S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412']

# %% [markdown]
# ### Downloading and processing Sentinel 2 products

# %% [markdown]
# #### Downloading and preparing Sentinel 2 products

# %%
# NBVAL_IGNORE_OUTPUT
product_asset_list = []
bands = ["B04", "B08"]
download_directory = TEST_TMP_DIR / "example_s2_download_and_processing"

for p in product_list:
    processed_product = download_and_process_sentinel2_asset(
        product_id=p, product_bands=bands, base_directory=download_directory, target_projection=5070
    )

    product_asset_list.append(processed_product)
# Out:
# [2025-05-22 14:12:17] INFO       [MainThread][geospatial_tools.stac] Initiating STAC API search
# [2025-05-22 14:12:18] INFO       [MainThread][geospatial_tools.planetary_computer.sentinel_2] [<Item id=S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346>]
# [2025-05-22 14:12:18] INFO       [MainThread][geospatial_tools.stac] Downloading [S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346] ...
# [2025-05-22 14:12:18] INFO       [MainThread][geospatial_tools.stac] Downloading B04 from https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/10/S/DJ/2024/07/05/S2A_MSIL2A_20240705T185921_N0510_R013_T10SDJ_20240706T050346.SAFE/GRANULE/L2A_T10SDJ_A047200_20240705T190418/IMG_DATA/R10m/T10SDJ_20240705T185921_B04_10m.tif?st=2025-05-21T18%3A12%3A16Z&se=2025-05-22T18%3A57%3A16Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-05-22T14%3A18%3A43Z&ske=2025-05-29T14%3A18%3A43Z&sks=b&skv=2024-05-04&sig=pjoW8ExBmQ6wXXL51%2B2r0zxn47D6PvEoHp45HLt%2BVXs%3D
# [2025-05-22 14:12:38] INFO       [MainThread][geospatial_tools.utils] Downloaded /home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_B04.tif successfully.
# [2025-05-22 14:12:38] INFO       [MainThread][geospatial_tools.stac] Downloading B08 from https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/10/S/DJ/2024/07/05/S2A_MSIL2A_20240705T185921_N0510_R013_T10SDJ_20240706T050346.SAFE/GRANULE/L2A_T10SDJ_A047200_20240705T190418/IMG_DATA/R10m/T10SDJ_20240705T185921_B08_10m.tif?st=2025-05-21T18%3A12%3A16Z&se=2025-05-22T18%3A57%3A16Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-05-22T14%3A18%3A43Z&ske=2025-05-29T14%3A18%3A43Z&sks=b&skv=2024-05-04&sig=pjoW8ExBmQ6wXXL51%2B2r0zxn47D6PvEoHp45HLt%2BVXs%3D
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.utils] Downloaded /home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_B08.tif successfully.
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.planetary_computer.sentinel_2] [<geospatial_tools.stac.Asset object at 0x731afe253410>]
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.stac] Creating merged asset metadata
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.raster] Creating merged asset metadata
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.raster] Calculated a total of [2] bands
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.raster] Merging asset [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_merged.tif] ...
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.raster] Writing band image: S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_B04.tif
# [2025-05-22 14:12:57] INFO       [MainThread][geospatial_tools.raster] Writing asset sub item band 1 to merged index band 1
# [2025-05-22 14:12:59] INFO       [MainThread][geospatial_tools.raster] Writing band image: S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_B08.tif
# [2025-05-22 14:12:59] INFO       [MainThread][geospatial_tools.raster] Writing asset sub item band 1 to merged index band 2
# [2025-05-22 14:13:00] INFO       [MainThread][geospatial_tools.stac] Asset [S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346] merged successfully
# [2025-05-22 14:13:00] INFO       [MainThread][geospatial_tools.stac] Asset location : [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_merged.tif]
# [2025-05-22 14:13:00] INFO       [MainThread][geospatial_tools.stac] Reprojecting asset [S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346] ...
# [2025-05-22 14:13:00] INFO       [MainThread][geospatial_tools.stac] Creating EPSG code from following input : [5070]
# [2025-05-22 14:13:06] INFO       [MainThread][geospatial_tools.stac] Reprojected file created at /home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_reprojected.tif
# [2025-05-22 14:13:06] INFO       [MainThread][geospatial_tools.stac] Asset location : [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_reprojected.tif]
# [2025-05-22 14:13:06] INFO       [MainThread][geospatial_tools.stac] Initiating STAC API search
# [2025-05-22 14:13:07] INFO       [MainThread][geospatial_tools.planetary_computer.sentinel_2] [<Item id=S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412>]
# [2025-05-22 14:13:07] INFO       [MainThread][geospatial_tools.stac] Downloading [S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412] ...
# [2025-05-22 14:13:07] INFO       [MainThread][geospatial_tools.stac] Downloading B04 from https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/10/T/DK/2024/07/05/S2A_MSIL2A_20240705T185921_N0510_R013_T10TDK_20240706T050412.SAFE/GRANULE/L2A_T10TDK_A047200_20240705T190418/IMG_DATA/R10m/T10TDK_20240705T185921_B04_10m.tif?st=2025-05-21T18%3A12%3A16Z&se=2025-05-22T18%3A57%3A16Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-05-22T14%3A18%3A43Z&ske=2025-05-29T14%3A18%3A43Z&sks=b&skv=2024-05-04&sig=pjoW8ExBmQ6wXXL51%2B2r0zxn47D6PvEoHp45HLt%2BVXs%3D
# [2025-05-22 14:13:29] INFO       [MainThread][geospatial_tools.utils] Downloaded /home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_B04.tif successfully.
# [2025-05-22 14:13:29] INFO       [MainThread][geospatial_tools.stac] Downloading B08 from https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/10/T/DK/2024/07/05/S2A_MSIL2A_20240705T185921_N0510_R013_T10TDK_20240706T050412.SAFE/GRANULE/L2A_T10TDK_A047200_20240705T190418/IMG_DATA/R10m/T10TDK_20240705T185921_B08_10m.tif?st=2025-05-21T18%3A12%3A16Z&se=2025-05-22T18%3A57%3A16Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-05-22T14%3A18%3A43Z&ske=2025-05-29T14%3A18%3A43Z&sks=b&skv=2024-05-04&sig=pjoW8ExBmQ6wXXL51%2B2r0zxn47D6PvEoHp45HLt%2BVXs%3D
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.utils] Downloaded /home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_B08.tif successfully.
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.planetary_computer.sentinel_2] [<geospatial_tools.stac.Asset object at 0x731afde583d0>]
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.stac] Creating merged asset metadata
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.raster] Creating merged asset metadata
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.raster] Calculated a total of [2] bands
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.raster] Merging asset [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_merged.tif] ...
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.raster] Writing band image: S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_B04.tif
# [2025-05-22 14:13:52] INFO       [MainThread][geospatial_tools.raster] Writing asset sub item band 1 to merged index band 1
# [2025-05-22 14:13:53] INFO       [MainThread][geospatial_tools.raster] Writing band image: S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_B08.tif
# [2025-05-22 14:13:53] INFO       [MainThread][geospatial_tools.raster] Writing asset sub item band 1 to merged index band 2
# [2025-05-22 14:13:55] INFO       [MainThread][geospatial_tools.stac] Asset [S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412] merged successfully
# [2025-05-22 14:13:55] INFO       [MainThread][geospatial_tools.stac] Asset location : [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_merged.tif]
# [2025-05-22 14:13:55] INFO       [MainThread][geospatial_tools.stac] Reprojecting asset [S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412] ...
# [2025-05-22 14:13:55] INFO       [MainThread][geospatial_tools.stac] Creating EPSG code from following input : [5070]
# [2025-05-22 14:14:00] INFO       [MainThread][geospatial_tools.stac] Reprojected file created at /home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_reprojected.tif
# [2025-05-22 14:14:00] INFO       [MainThread][geospatial_tools.stac] Asset location : [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_reprojected.tif]

# %%
for p in product_asset_list:
    print(f"Asset ID : [{p.asset_id}]")
    print(f"Reprojected ID path : \n[{p.reprojected_asset_path}]\n")
# Out:
# Asset ID : [S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346]
# Reprojected ID path :
# [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_reprojected.tif]
#
# Asset ID : [S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412]
# Reprojected ID path :
# [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/S2A_MSIL2A_20240705T185921_R013_T10TDK_20240706T050412_reprojected.tif]

# %%
# Here, we are creating a new Asset object simply for convenience, from the printed outputs above

product = Asset(
    asset_id="S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346",
    reprojected_asset=download_directory / "S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_reprojected.tif",
)

# %% [markdown]
# #### Creating a new geodataframe of all the vector polygons that are within our selected product

# %%
s2_product_id = product.asset_id
product_path = product.reprojected_asset_path
product_id_series = group_by_product[group_by_product["best_s2_product_id"] == s2_product_id]
# Since it's grouped by product id, there should always be only one row in the series
feature_ids = product_id_series["feature_id"].iloc[0]
vector_features = best_results[best_results["feature_id"].isin(feature_ids)]
vector_features_path = TEST_TMP_DIR / "vector_features.gpkg"
to_geopackage(vector_features, TEST_TMP_DIR / "vector_features.gpkg")
# Out:
# [2025-05-22 14:14:00] INFO       [MainThread][geospatial_tools.vector] Starting writing process
# [2025-05-22 14:14:00] INFO       [MainThread][geospatial_tools.vector] File [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/vector_features.gpkg] took 0.009784221649169922 seconds to write.
# PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/vector_features.gpkg')

# %% [markdown]
# #### Creating our Sentinel 2 "chips" by clipping main products with our vector polygon grid

# %%
clip_list = clip_raster_with_polygon(
    raster_image=product_path,
    polygon_layer=vector_features_path,
    base_output_filename=s2_product_id,
    output_dir=download_directory / "test_sentinel2_clip",
)
# Out:
# [2025-05-22 14:14:00] INFO       [MainThread][geospatial_tools.raster] Number of workers used: 16
# [2025-05-22 14:14:00] INFO       [MainThread][geospatial_tools.raster] Output path : [/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip]
# [2025-05-22 14:14:00] INFO       [MainThread][geospatial_tools.raster] Clipping raster image with 73 polygons
# [2025-05-22 14:14:02] INFO       [MainThread][geospatial_tools.raster] Clipping process finished

# %%
sorted(clip_list)
# Out:
# [PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_0.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_1.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_10.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_11.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_12.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_13.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_14.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_15.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_16.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_17.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_18.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_19.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_2.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_20.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_21.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_22.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_23.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_24.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_25.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_26.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_27.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_28.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_29.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_3.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_30.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_31.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_32.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_33.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_34.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_35.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_36.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_37.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_38.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_39.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_4.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_40.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_41.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_42.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_43.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_44.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_45.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_46.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_47.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_48.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_49.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_5.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_50.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_51.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_52.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_53.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_54.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_55.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_56.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_57.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_58.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_59.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_6.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_60.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_61.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_62.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_63.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_64.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_65.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_66.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_67.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_68.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_69.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_7.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_70.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_71.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_72.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_8.tif'),
#  PosixPath('/home/francispelletier/projects/geospatial_tools/tests/test_notebooks/tmp_sentinel2/example_s2_download_and_processing/test_sentinel2_clip/S2A_MSIL2A_20240705T185921_R013_T10SDJ_20240706T050346_clipped_9.tif')]

# %%
shutil.rmtree(TEST_TMP_DIR)
